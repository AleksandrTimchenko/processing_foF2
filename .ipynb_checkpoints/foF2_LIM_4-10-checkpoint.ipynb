# %%
import numpy
import pandas
import matplotlib
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:160: UserWarning: pylab import has clobbered these variables: ['e', 'sum']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
data = loadtxt('AVD09dayli.DAT') # файл содержащий значения foF2, за день 
N = len(data) # количество дней 
Ni = int(N/2)
t = arange(0,N) # количество дней
a = arange(1, Ni) # параметр 
b = arange(0, N) # параметр

# %%
#функция вейвлет преобразования Морле
def morley(x):
    m = real(exp(-x**2/2)*exp(1j*2*pi*x))
    return m

# %%
foF2av = mean(data[:,1]) # среднее значение foF2 за данный промежуток 
foF2 = data[:,1]
#foF2 = data[:,1]
#for i in range(0,N-1):
   # foF2[i+1] = data[i+1,1] -data[i,1]
plot(foF2)

# %%
# Вейвлет преобразование Морле
Np = 30
WA = np.zeros(Np*N).reshape(Np,N)
for i in range(1,Np):
    for j in range(0,N):
        sum = 0
        for e in range(0,N):
            sum = sum + (foF2[e] - foF2av)*morley((t[e]-b[j])/a[i])
        WA[i,j] = sum/a[i]

# %%
contourf((WA)**2, 35)
colorbar()

# %%
# LIM метод
W = abs(WA)**2
LIM = np.zeros(Np*N).reshape(Np,N)

#print(W)
for i in range(1,Np):
    S = np.mean(W[i,:])
    #print(S)
    for j in range(0,N):
        LIM[i,j] = W[i,j]/S

# %%
contourf(LIM, 35)
colorbar()

# %%
contourf(W[1:15, 1:60])
colorbar()

# %%
k = 0
data = zeros(3*Np*N).reshape(Np*N,3)
for i in range(1,Np):
    for j in range(1,N):
        data[k,0] = j
        data[k,1] = i
        data[k,2] = LIM[i,j]
        k = k+1
savetxt("LIM_2009.dat", data)
